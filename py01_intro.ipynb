# %% [markdown]
# <a href="https://colab.research.google.com/github/JakeOh/202208_itw_java134_lab_python/blob/main/py01_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python 버전 확인

# %%
# !python --version
# Out:
# Python 3.8.16

# %% [markdown]
# 코드셀에서 명령창(command prompt)에서 실행하는 문장을 작성하고 실행할 때는 !로 시작.

# %% [markdown]
# # `print` 함수

# %%
print('안녕, 파이썬!')
# Out:
# 안녕, 파이썬!

# %%
print('hello', 'python', '안녕', '파이썬')
# Out:
# hello python 안녕 파이썬

# %% [markdown]
# `print()` 함수에 여러개의 argument를 전달하면, arugment들을 공백으로 연결해서 한 줄에 출력함.

# %%
print('hello', 'python', sep='::')
# Out:
# hello::python

# %% [markdown]
# ## `format()` 메서드를 사용한 출력

# %%
print('{} + {} = {}'.format(1, 2, 3))
# Out:
# 1 + 2 = 3

# %%
print('{x} + {y} = {z}'.format(x=1, y=2, z=3))
# Out:
# 1 + 2 = 3

# %% [markdown]
# ## formatted string을 사용한 출력
#
# Python 3.6 이상 버전에서만 사용 가능.

# %%
a = 10
b = 20

# %%
print(f'{a} + {b} = {a + b}')
# Out:
# 10 + 20 = 30

# %% [markdown]
# # 코드셀 실행 방법
#
# * 코드셀 왼쪽의 실행 버튼 클릭
# * Ctrl+Enter: 현재 포커스가 있는 셀을 실행.
# * Shift+Enter: 현재 포커스가 있는 셀을 실행하고, 그 다음 셀로 포커스를 이동.
#   * 현재 셀 아래에 다음 셀이 없는 경우에는 새로운 코드 셀을 생성.
# * 런타임 메뉴
